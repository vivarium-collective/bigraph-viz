# %%
from bigraph_viz import plot_bigraph

# %%
composite_spec = {
    'params1': {
            'k1': 0.1,
            'k2': 0.2,
    },
    'params2': {
            'k1': 0.5,
            'k2': 0.3,
    },
    'model_update': {},
    'process1': {
        '_type': 'process',
        '_address': 'kisao:000000694',
        'config': {
            'sbml_file': 'path/to/sbml/file.xml',
        },
        # '_inputs': {
        #     'params': 'map[string,float]',  # from kisao:00000694
        # },
        'inputs': {
            'params': 'params1',
        },
        'outputs': {
            'results': 'results1',
        }
    },
    'process2': {
        '_type': 'process',
        '_address': 'kisao:00000019',
        'config': {
            'sbml_file': 'path/to/sbml/file.xml',
        },
        'inputs': {
            'params': 'params2',
        },
        'outputs': {
            'results': 'results2',
        }
    },
    'compare_results': {
        '_type': 'process',
        '_address': 'kisao:0000216',
        # 'config': {
        #     'dimension1': 'results1',
        # },
        'inputs': {
            'results1': 'results1',
            'results2': 'results2',
        },
        'outputs': {
            'comparison': 'comparison output',
        }
    },
}
