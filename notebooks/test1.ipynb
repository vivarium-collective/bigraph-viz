# %%
from bigraph_viz import plot_bigraph
from process_bigraph import Composite

# %%
# use case 1 interactive composition development
your_composite = {
    'ocean_model': {
        '_type': 'process',
        '_inputs': {
            'port1': 'any'  # TODO -- this should be unnecessary. Should come from the inputs wiring
        },
        'inputs': {
            'port1': ['store1']
        }
    },
    'store2': {
        'store2.1': {},
        'store2.2': {}
    }
}

your_schema = {}

plot_bigraph(your_composite)

# %%
# use case 1 interactive composition development
your_composite = {
    'ocean_model': {
        '_type': 'process',
        'config': {},
        'address': '',
        '_inputs': {
            'port1': 'any'  # TODO -- this should be unnecessary. Should come from the inputs wiring
        },
        'inputs': {
            'port1': ['store1']
        }
    },
    'store2': {
        'store2.1': {},
        'store2.2': {

        }
    }
}

your_schema = {
    # 'store2': {
    #     'store2.2': {
    #         'ocean_model': {
    #             '_type': 'process',
    #             '_inputs': {
    #                 'port1': 'any'  # TODO -- this should be unnecessary. Should come from the inputs wiring
    #             },
    #         }
    #     }
    # }
}

plot_bigraph(state=your_composite, schema=your_schema)

# %%
sim = Composite(composite=your_composite)
sim.run(1)

# %%
# use case 2 visualizing existing composites.
# pass in schema and state

# %%
help(plot_bigraph)
# Out:
# Help on function plot_bigraph in module bigraph_viz.diagram:
#
# plot_bigraph(state, schema=None, core=None, out_dir=None, filename=None, file_format='png', size='16,10', node_label_size='12pt', show_values=False, show_types=False, port_labels=True, port_label_size='10pt', rankdir='TB', print_source=False, dpi='70', label_margin='0.05', node_border_colors=None, node_fill_colors=None, node_groups=False, remove_nodes=None, invisible_edges=False, remove_process_place_edges=False, show_process_schema_keys=[])
