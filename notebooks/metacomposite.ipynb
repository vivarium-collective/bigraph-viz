# %%
from bigraph_viz import plot_bigraph, VisualizeTypes

core = VisualizeTypes()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from bigraph_viz import plot_bigraph, VisualizeTypes
#       3 core = VisualizeTypes()
#
# File ~/code/bigraph-viz/bigraph_viz/__init__.py:2
#       1 import pprint
# ----> 2 from bigraph_viz.visualize_types import VisualizeTypes, plot_bigraph, get_graphviz_fig
#       3 from bigraph_viz.dict_utils import replace_regex_recursive
#       6 pretty = pprint.PrettyPrinter(indent=2)
#
# File ~/code/bigraph-viz/bigraph_viz/visualize_types.py:9
#       6 import graphviz
#       7 import numpy as np
# ----> 9 from bigraph_schema import TypeSystem, is_schema_key, hierarchy_depth
#      10 from bigraph_viz.dict_utils import absolute_path
#      12 # Constants
#
# File ~/code/bigraph-schema/bigraph_schema/__init__.py:11
#       8 from bigraph_schema.protocols import local_lookup_module
# ...
